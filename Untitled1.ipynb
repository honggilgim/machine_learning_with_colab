# %%
a = (1,3,5)
b = (2,4,6)

# 벡터 외적의 수식을 함수로 구현

def cross(a,b):
  c = [a[1]*b[2] - a[2]*b[1],
       a[2]*b[0] - a[0]*b[2],
       a[0]*b[1] - a[1]*b[0]]

  return c

# 함수 호출로 벡터의 외적을 계산합니다.
cross(a,b)
# Out:
# [-2, 4, -2]

# %%
import numpy as np
print(np.cross(a,b)) # cross 함수를 이용한 결과
# Out:
# [-2  4 -2]
