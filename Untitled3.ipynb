# %%
A = [[2,3], [1,2]]

# %%
A * A
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-9bb3fd0dd66e> in <module>()
# ----> 1 A * A
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
import numpy as np

# %%
ar = np.array(A)

# %%
A * A
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-9bb3fd0dd66e> in <module>()
# ----> 1 A * A
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
arr = np.array([[2,3],[1,2]])

# %%
arr * arr
# Out:
# array([[4, 9],
#        [1, 4]])

# %%
print(arr)
# Out:
# [[2 3]
#  [1 2]]
